# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Linter - Verificações de Boas Práticas

# %%
# !python -m pylint modulo_05_main.py
# Out:
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)

# %%
# !python -m pycodestyle modulo_05_main.py
# Out:
# modulo_05_main.py:7:80: E501 line too long (96 > 79 characters)

# %%
# !python -m pylint modulo_05_function.py
# Out:
# --------------------------------------------------------------------
# Your code has been rated at 10.00/10 (previous run: 10.00/10, +0.00)

# %%
# !python -m pycodestyle modulo_05_function.py
# Out:
# modulo_05_function.py:2:1: E302 expected 2 blank lines, found 0
